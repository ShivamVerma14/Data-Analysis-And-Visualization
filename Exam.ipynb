# %%
import pandas as pd

# %%
import numpy as np

# %%
dateRange = pd.date_range('2021-01-01', '2021-12-31', freq='WOM-2TUE')
dateRange
# Out:
# DatetimeIndex(['2021-01-12', '2021-02-09', '2021-03-09', '2021-04-13',
#                '2021-05-11', '2021-06-08', '2021-07-13', '2021-08-10',
#                '2021-09-14', '2021-10-12', '2021-11-09', '2021-12-14'],
#               dtype='datetime64[ns]', freq='WOM-2TUE')

# %%
pd.Series(np.random.randn(12), index=dateRange)
# Out:
# 2021-01-12   -1.332629
# 2021-02-09   -0.357972
# 2021-03-09    0.578378
# 2021-04-13   -1.950457
# 2021-05-11   -0.164615
# 2021-06-08   -0.327033
# 2021-07-13    0.170051
# 2021-08-10   -0.183531
# 2021-09-14   -0.323526
# 2021-10-12   -1.035663
# 2021-11-09    0.055269
# 2021-12-14   -0.920622
# Freq: WOM-2TUE, dtype: float64

# %%
pd.Series(np.random.randn(20), index=pd.date_range(end='2021-01-31', periods=20))
# Out:
# 2021-01-12   -0.542251
# 2021-01-13   -0.914591
# 2021-01-14    1.904866
# 2021-01-15   -0.639362
# 2021-01-16   -1.940233
# 2021-01-17    0.705330
# 2021-01-18   -0.257897
# 2021-01-19    0.444892
# 2021-01-20    0.059379
# 2021-01-21    1.203948
# 2021-01-22   -0.787952
# 2021-01-23    0.868807
# 2021-01-24   -1.723975
# 2021-01-25   -0.424906
# 2021-01-26    0.240252
# 2021-01-27    0.771273
# 2021-01-28    1.159349
# 2021-01-29   -0.005407
# 2021-01-30    0.472919
# 2021-01-31    0.051418
# Freq: D, dtype: float64

# %%
DF = pd.DataFrame(np.random.randint(500, high=1000, size=31), index=pd.date_range('2021-01-01', '2021-01-31'), columns=['Sale'])

# %%
DF
# Out:
#             Sale
# 2021-01-01   888
# 2021-01-02   761
# 2021-01-03   865
# 2021-01-04   506
# 2021-01-05   995
# 2021-01-06   585
# 2021-01-07   766
# 2021-01-08   767
# 2021-01-09   843
# 2021-01-10   744
# 2021-01-11   879
# 2021-01-12   781
# 2021-01-13   705
# 2021-01-14   560
# 2021-01-15   869
# 2021-01-16   737
# 2021-01-17   611
# 2021-01-18   826
# 2021-01-19   839
# 2021-01-20   838
# 2021-01-21   511
# 2021-01-22   896
# 2021-01-23   759
# 2021-01-24   601
# 2021-01-25   591
# 2021-01-26   800
# 2021-01-27   557
# 2021-01-28   653
# 2021-01-29   608
# 2021-01-30   567
# 2021-01-31   598

# %%
DF['Moving Avg'] = DF.Sale.rolling(5).mean()

# %%
DF
# Out:
#             Sale  Moving Avg
# 2021-01-01   888         NaN
# 2021-01-02   761         NaN
# 2021-01-03   865         NaN
# 2021-01-04   506         NaN
# 2021-01-05   995       803.0
# 2021-01-06   585       742.4
# 2021-01-07   766       743.4
# 2021-01-08   767       723.8
# 2021-01-09   843       791.2
# 2021-01-10   744       741.0
# 2021-01-11   879       799.8
# 2021-01-12   781       802.8
# 2021-01-13   705       790.4
# 2021-01-14   560       733.8
# 2021-01-15   869       758.8
# 2021-01-16   737       730.4
# 2021-01-17   611       696.4
# 2021-01-18   826       720.6
# 2021-01-19   839       776.4
# 2021-01-20   838       770.2
# 2021-01-21   511       725.0
# 2021-01-22   896       782.0
# 2021-01-23   759       768.6
# 2021-01-24   601       721.0
# 2021-01-25   591       671.6
# 2021-01-26   800       729.4
# 2021-01-27   557       661.6
# 2021-01-28   653       640.4
# 2021-01-29   608       641.8
# 2021-01-30   567       637.0
# 2021-01-31   598       596.6

# %%
DF.plot()
# Out:
# <AxesSubplot:>

# %%
List1 = ['Good Morning', 'Good Evening', 'Hello', 'Good Afternoon', 'Greetings', 'Good Morning', 'Nice to see you']

Newlist = [x for x in List1 if x not in Newlist]
Newlist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5256/2984859106.py in <module>
#       1 List1 = ['Good Morning', 'Good Evening', 'Hello', 'Good Afternoon', 'Greetings', 'Good Morning', 'Nice to see you']
#       2
# ----> 3 Newlist = [x for x in List1 if x not in Newlist]
#       4 Newlist
#
# ~\AppData\Local\Temp/ipykernel_5256/2984859106.py in <listcomp>(.0)
#       1 List1 = ['Good Morning', 'Good Evening', 'Hello', 'Good Afternoon', 'Greetings', 'Good Morning', 'Nice to see you']
#       2
# ----> 3 Newlist = [x for x in List1 if x not in Newlist]
#       4 Newlist
#
# NameError: name 'Newlist' is not defined

# %%
np.random.randint(55, high=150, size=100)
# Out:
# array([142, 107, 141,  82,  84, 141,  98, 117,  71,  85, 135,  88, 120,
#        142,  56, 111,  89, 129,  95,  62, 103,  60,  55, 112,  64, 116,
#        138,  57, 104,  65,  82,  74, 108, 140,  92, 130, 118, 135, 111,
#        117, 135,  91,  55, 127, 126,  83, 149,  78,  83, 136,  98,  56,
#        111, 122, 131,  98,  63,  62, 131, 132, 102, 113, 148, 117, 140,
#         80,  56,  73, 134,  60,  64, 143,  83, 127, 104,  61,  99, 100,
#         85,  64,  58,  57, 141,  74, 133, 121, 121,  67, 100, 144, 133,
#         89, 143,  90,  84,  85,  86, 113,  87, 108])
